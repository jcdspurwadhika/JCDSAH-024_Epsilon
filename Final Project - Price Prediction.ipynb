# %% [markdown]
# # **Saudi Arabia Used Car Price Analysis**
# ****
# **Sumber dataset** https://www.kaggle.com/datasets/turkibintalib/saudi-arabia-used-cars-dataset
#
# ****
# ## **Business Problem Understanding**
# ### **Context**
# Di era digital ini untuk orang yang ingin membeli mobil sudah sangat dimudahkan dengan adanya internet. Kemudahan yang didapat adalah bisa mencari dan membandingkan mobil sesuai impian atau pilihan mereka tanpa datang lebih dulu. Salah satunya platform website penjualan mobil bekas di Arab Saudi yaitu www.syarah.com.
#
# Penjual pun sangat dimudahkan dalam memasarkan mobil yang dijualnya untuk menjangkau pasar yang lebih luas. Namun, untuk penjual itu menjadi sebuah tantangan dalam menentukan harga yang sesuai. Dimana kalau harga tidak sesuai atau contoh terlalu mahal atau terlalu rendah, berpotensi menyebabkan pendapatan yang tidak maksimal dan waktu penjualan yang lama.
#
# ### **Problem Statement**
# Bagaimana membangun sistem estimasi harga mobil bekas yang mampu merepresentasikan nilai pasar berdasarkan karakteristik kendaraan, sehingga membantu penjual menentukan harga yang kompetitif dan meningkatkan peluang terjadinya transaksi?
#
# ### **Stakeholder**
# Stakeholder dalam analisis ini meliputi:
# 1. Platform syarah.com, sebagai penyedia marketplace kendaraan mobil bekas yang berkepentingan dalam meningkatkan jumlah transaksi dan menjaga kredibilitas harga di platform.
#
# 2. Penjual kendaraan, yang membutuhkan referensi harga agar tidak mengalami lost profit akibat underpricing maupun keterlambatan penjualan akibat harga yang terlalu mahal atau overprice.
#
# 3. Calon pembeli, yang diuntungkan dengan harga yang lebih transparan dan sesuai dengan kondisi pasar.
#
# ### **Goal**
# Tujuan dari analisis ini adalah membangun model machine learning berbasis data listing mobil bekas untuk memprediksi dan mengestimasi harga pasar berdasarkan spesifikasi kendaraan. Model ini dirancang sebagai sistem rekomendasi harga yang dapat diintegrasikan ke dalam platform marketplace, sehingga membantu penjual menentukan harga yang lebih optimal dan kompetitif sesuai kondisi pasar.
#
# Implementasi model ini diharapkan memberikan beberapa manfaat strategis, antara lain:
#
# - Meningkatkan Profit Penjual
# Dengan estimasi harga yang lebih akurat, penjual dapat menghindari underpricing yang berpotensi menyebabkan kehilangan keuntungan. Harga yang sesuai dengan nilai pasar memungkinkan penjual memaksimalkan profit tanpa kehilangan daya saing.
#
# - Mempercepat Waktu Penjualan
# Penetapan harga yang terlalu tinggi sering kali membuat mobil sulit terjual. Rekomendasi harga berbasis data membantu menjaga harga tetap kompetitif, sehingga mempercepat proses transaksi.
#
# - Meningkatkan Kepercayaan Pengguna terhadap Platform
# Fitur seperti “Suggested Market Price” meningkatkan transparansi harga dan memberikan referensi objektif kepada penjual maupun pembeli, sehingga memperkuat kredibilitas platform.
#
# - Meningkatkan Conversion Rate Platform
# Harga yang lebih rasional dan sesuai pasar meningkatkan peluang terjadinya transaksi. Hal ini berpotensi meningkatkan volume penjualan dan revenue platform, terutama jika model bisnis berbasis komisi.
#
# ### **Analytic Approach**
# Data akan dianalisis menggunakan pendekatan Exploratory Data Analysis (EDA) untuk menemukan pola dan hubungan antar fitur yang memengaruhi harga mobil bekas. Selanjutnya, akan dibangun model Machine Learning berbasis regresi untuk memprediksi harga mobil di platform syarah.com. Pendekatan regresi dipilih karena target variabel yang ingin diprediksi adalah harga yaitu sebuah nilai numerik kontinu, bukan kategori.
# Penggunaan Machine Learning diperlukan karena penetapan harga secara manual rentan terhadap bias dan ketidakakuratan. Dengan Machine Learning, model dapat belajar dari data listing historis untuk menghasilkan estimasi harga yang lebih objektif dan berbasis data, sehingga membantu penjual menentukan harga yang kompetitif di platform syarah.com.
#
# ### **Evaluation Metric**
# Model regresi dievaluasi menggunakan beberapa metrik berikut untuk mengukur performa prediksi harga:
#
# 1. MAE (Mean Absolute Error)
# Mengukur rata-rata selisih absolut antara harga aktual dan harga prediksi dalam satuan SAR.
# MAE dipilih karena mudah diinterpretasikan oleh stakeholder bisnis dan secara langsung merepresentasikan rata-rata kesalahan harga yang terjadi pada setiap prediksi.
#
# 2. RMSE (Root Mean Squared Error)
# Mengukur akar dari rata-rata kuadrat error.
# RMSE memberikan penalti lebih besar terhadap error yang ekstrem (outlier), sehingga membantu mengidentifikasi apakah model menghasilkan kesalahan besar pada mobil dengan harga sangat tinggi atau sangat rendah.
#
# 3. MAPE (Mean Absolute Percentage Error)
# Mengukur rata-rata persentase kesalahan prediksi terhadap harga aktual.
# MAPE membantu memahami besar kesalahan dalam bentuk persentase, sehingga lebih intuitif untuk membandingkan performa model pada berbagai rentang harga.
#
# 4. R² Score
# Mengukur seberapa besar variasi harga mobil yang dapat dijelaskan oleh fitur-fitur dalam model.
# Nilai R² yang mendekati 1 menunjukkan bahwa model mampu menjelaskan sebagian besar variasi harga di dalam dataset.

# %% [markdown]
# ## **Data Understanding**
# - Dataset yang digunakan berasal dari syarah.com dan terdiri dari 8.248 data listing mobil bekas.
# - Setiap baris merepresentasikan satu kendaraan dengan informasi meliputi merek, model, tahun produksi, asal kendaraan, warna, kelengkapan fitur, kapasitas mesin, jenis bahan bakar, tipe transmisi, jarak tempuh, wilayah, harga, dan status negosiasi.
#
# | **Attribute** | **Data Type** | **Description**                                       |
# | ------------- | ------------- | ----------------------------------------------------- |
# | Link          | Object        | Link iklan mobil                                      |
# | Make          | Object        | Merek mobil                                           |
# | Type          | Object        | Tipe atau model mobil                                 |
# | Year          | Integer       | Tahun produksi mobil                                  |
# | Origin        | Object        | Negara asal kendaraan                                 |
# | Color         | Object        | Warna mobil                                           |
# | Options       | Object        | Tingkat kelengkapan fitur (Standard, Semi Full, Full) |
# | Engine_Size   | Float         | Kapasitas mesin dalam liter                           |
# | Fuel_Type     | Object        | Jenis bahan bakar                                     |
# | Gear_Type     | Object        | Jenis transmisi (Manual / Automatic)                  |
# | Condition     | Object        | Kondisi kendaraan (New / Used)                        |
# | Mileage       | Integer       | Jarak tempuh kendaraan (km)                           |
# | Region        | Object        | Wilayah tempat mobil dijual                           |
# | Price         | Object        | Harga jual mobil dalam SAR                            |
# | Negotiable    | Boolean       | Status apakah harga dapat dinegosiasikan              |

# %%
# Import library 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
raw = pd.read_csv("UsedCarsSA_Unclean_EN.csv")

# %%
# Copy dataset 
df = raw.copy()

# %%
# 10 baris pertama dataset
df.head(10)
# Out:
#                                                 Link       Make          Type  \
# 0  https://syarah.com/%D9%83%D8%B1%D8%A7%D9%8A%D8...   Chrysler          C300
# 1  https://syarah.com/%D9%86%D9%8A%D8%B3%D8%A7%D9...     Nissan        Patrol
# 2  https://syarah.com/online/%D9%86%D9%8A%D8%B3%D...     Nissan         Sunny
# 3  https://syarah.com/online/%D9%87%D9%88%D9%86%D...    Hyundai       Elantra
# 4  https://syarah.com/online/%D9%87%D9%88%D9%86%D...    Hyundai       Elantra
# 5  https://syarah.com/%D9%87%D9%88%D9%86%D8%AF%D8...      Honda        Accord
# 6  https://syarah.com/%D8%AA%D9%88%D9%8A%D9%88%D8...     Toyota  Land Cruiser
# 7  https://syarah.com/%D8%AC%D9%8A_%D8%A5%D9%85_%...        GMC         Yukon
# 8  https://syarah.com/%D8%B4%D9%81%D8%B1%D9%88%D9...  Chevrolet        Impala
# 9  https://syarah.com/%D8%AA%D9%88%D9%8A%D9%88%D8...     Toyota         Yaris
#
#    Year Origin   Color    Options  Engine_Size Fuel_Type  Gear_Type Condition  \
# ...

# %%
# Informasi dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8248 entries, 0 to 8247
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Link         8248 non-null   object
#  1   Make         8248 non-null   object
#  2   Type         8248 non-null   object
#  3   Year         8248 non-null   int64
#  4   Origin       8153 non-null   object
#  5   Color        8248 non-null   object
#  6   Options      8139 non-null   object
#  7   Engine_Size  5982 non-null   float64
#  8   Fuel_Type    8248 non-null   object
#  9   Gear_Type    8174 non-null   object
#  10  Condition    8248 non-null   object
#  11  Mileage      8248 non-null   int64
#  12  Region       8248 non-null   object
#  13  Price        8248 non-null   object
#  14  Negotiable   8248 non-null   bool
# dtypes: bool(1), float64(1), int64(2), object(11)
# memory usage: 910.3+ KB

# %% [markdown]
# ## **Data Cleaning**

# %%
# Cek duplikasi data
df.duplicated().sum()
# Out:
# np.int64(20)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Terdapat 20 baris duplicate lalu kita drop

# %%
# Cek persentase missing value
df.isnull().sum()*100/len(df)
# Out:
# Link            0.000000
# Make            0.000000
# Type            0.000000
# Year            0.000000
# Origin          1.154594
# Color           0.000000
# Options         1.324745
# Engine_Size    27.503646
# Fuel_Type       0.000000
# Gear_Type       0.899368
# Condition       0.000000
# Mileage         0.000000
# Region          0.000000
# Price           0.000000
# Negotiable      0.000000
# dtype: float64

# %%
# Missing value heatmap
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
# Korelasi antar missing value
df[["Origin","Options","Gear_Type"]].isna().corr()
# Out:
#              Origin   Options  Gear_Type
# Origin     1.000000  0.753662   0.833241
# Options    0.753662  1.000000   0.653287
# Gear_Type  0.833241  0.653287   1.000000

# %% [markdown]
# Terdapat missing value pada fitur Origin, Options, Gear_Type, dan Engine_Size. Analisis korelasi missing menunjukkan bahwa Origin, Options, dan Gear_Type memiliki korelasi tinggi (>0.65), sehingga missing value pada ketiga fitur tersebut bersifat sistematis dan cenderung muncul pada baris yang sama. Karena proporsinya kecil (<2%), baris dengan missing pada fitur tersebut akan dihapus.
#
# Sementara itu Engine_Size memiliki missing value yang cukup besar (27.5%), sehingga dilakukan imputasi menggunakan median berdasarkan kombinasi Make dan Type.

# %%
# Deskripsi dataset
listItem = []

for col in df.columns:
    unique_vals = df[col].drop_duplicates()
    sample_size = min(2, len(unique_vals))
    
    listItem.append([
        col,
        df[col].dtype,
        df[col].isna().sum(),
        round((df[col].isna().sum()/len(df[col])) * 100, 2),
        df[col].nunique(),
        list(unique_vals.sample(sample_size).values)
    ])

dfDesc = pd.DataFrame(
    columns=['dataFeatures', 'dataType', 'null', 'nullPct', 'unique', 'uniqueSample'],
    data=listItem
)

dfDesc
# Out:
#    dataFeatures dataType  null  nullPct  unique  \
# 0          Link   object     0     0.00    8228
# 1          Make   object     0     0.00      65
# 2          Type   object     0     0.00     435
# 3          Year    int64     0     0.00      55
# 4        Origin   object    95     1.15       3
# 5         Color   object     0     0.00      15
# 6       Options   object   109     1.32       3
# 7   Engine_Size  float64  2263    27.50      75
# 8     Fuel_Type   object     0     0.00       3
# 9     Gear_Type   object    74     0.90       2
# 10    Condition   object     0     0.00       1
# 11      Mileage    int64     0     0.00    2196
# 12       Region   object     0     0.00      27
# 13        Price   object     0     0.00     549
# 14   Negotiable     bool     0     0.00       2
#
#                                          uniqueSample
# 0   [https://syarah.com/%D8%AC%D9%8A%D8%A8_GX_%D9%...
# 1                                    [Pontiac, Isuzu]
# ...

# %% [markdown]
# Dataset terdiri dari fitur numerikal dan kategorikal yang merepresentasikan spesifikasi mobil bekas. Beberapa fitur penting untuk prediksi harga adalah **Year, Mileage, Engine_Size, Make, dan Type**, karena secara logis memengaruhi nilai pasar kendaraan. Kolom **Type (435 kategori)** dan **Make (65 kategori)** memiliki cardinality tinggi sehingga memerlukan strategi encoding khusus pada tahap preprocessing. Terdapat missing value pada **Origin, Options, Gear_Type**, dan terutama **Engine_Size (27.5%)** yang perlu ditangani sebelum modeling. Sementara itu, kolom seperti **Link** dan **Condition** kurang informatif dan berpotensi untuk di-drop karena tidak memberikan variasi atau tidak relevan terhadap prediksi harga.

# %%
# Drop column Link
df = df.drop(columns=["Link","Condition"])

# %%
# Cek nilai "Negotiable" pada kolom Price
(df["Price"] == "Negotiable").value_counts()
# Out:
# Price
# False    5636
# True     2592
# Name: count, dtype: int64

# %% [markdown]
# Berdasarkan pengamatan awal pada df.head(), ditemukan bahwa pada kolom Price terdapat beberapa baris dengan nilai "Negotiable" yang seharusnya berisi angka harga mobil. Hal ini menunjukkan adanya inkonsistensi tipe data karena kolom Price seharusnya bertipe numerik.

# %%
# Tampilkan 10 baris data dengan nilai "Negotiable" pada kolom Price
df[(df["Price"] == "Negotiable")].head(10)
# Out:
#          Make      Type  Year       Origin   Color    Options  Engine_Size  \
# 1      Nissan    Patrol  2016        Saudi   White       Full          4.8
# 7         GMC     Yukon  2009        Saudi  Bronze       Full          5.7
# 19        GMC     Yukon  2018        Saudi   White       Full          5.3
# 27     Toyota     Camry  2019        Saudi     Red       Full          2.5
# 29     Toyota    Avalon  2008        Other     Red       Full          NaN
# 60    Hyundai  Senta fe  2021        Saudi    Navy  Semi Full          NaN
# 78        Kia    Optima  2018        Saudi   Brown   Standard          2.0
# 86      Lexus        LX  2015        Saudi   White       Full          5.7
# 87      Lexus        GX  2018  Gulf Arabic   White  Semi Full          4.6
# 96  Chevrolet  Suburban  2015        Other   Black       Full          5.3
#
#    Fuel_Type  Gear_Type  Mileage  Region       Price  Negotiable
# 1        Gas  Automatic     5448  Riyadh  Negotiable        True
# ...

# %%
# Drop data dengan nilai "Negotiable" pada kolom Price
df = df[df["Price"] != "Negotiable"]

# %%
# Cek kembali nilai "Negotiable" pada kolom Price
df[(df["Price"] == "Negotiable")].sum()
# Out:
# Make             0
# Type             0
# Year             0
# Origin           0
# Color            0
# Options          0
# Engine_Size    0.0
# Fuel_Type        0
# Gear_Type        0
# Mileage          0
# Region           0
# Price            0
# Negotiable       0
# dtype: object

# %%
# Ubah tipe data kolom Price menjadi integer
df['Price'] = df['Price'].astype(int)

# %%
# Cek jumlah missing value pada kolom Price setelah diubah menjadi integer
df['Price'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Pada kolom Price terdapat nilai "Negotiable" yang bukan numerik, sehingga baris tersebut dihapus karena tidak dapat digunakan sebagai target regresi. Imputasi tidak dilakukan untuk menghindari bias, mengingat harga setiap mobil bersifat unik. Selanjutnya, tipe data Price dikonversi menjadi integer agar dapat digunakan dalam proses modeling.

# %%
df = df.drop(columns=["Negotiable"])

# %% [markdown]
# Kolom Negotiable dihapus dari dataset karena setelah proses pembersihan data, seluruh nilai pada kolom tersebut hanya tersisa satu kategori yaitu False. Dengan tidak adanya variasi nilai, variabel ini tidak lagi memberikan informasi yang dapat membantu analisis maupun pemodelan, sehingga dianggap tidak relevan.

# %%
# Cek data dengan nilai Price 0
df[(df["Price"] == 0)]
# Out:
#         Make       Type  Year Origin  Color    Options  Engine_Size Fuel_Type  \
# 3814  Toyota  Furniture  2012  Other  White  Semi Full          2.7       Gas
#
#       Gear_Type  Mileage  Region  Price
# 3814  Automatic   225000  Riyadh      0

# %%
# Drop data dengan nilai Price 0
df = df[df["Price"] != 0]

# %% [markdown]
# Terdapat satu baris dengan nilai Price sebesar 0, yang secara logika bisnis tidak realistis untuk transaksi mobil bekas. Nilai tersebut dianggap sebagai kesalahan input sehingga baris tersebut dihapus untuk menjaga kualitas data.

# %%
# Remove Harga mobil rendah, dikarenakan ini merupakan imputation error
# dan jumlah datanya sedikit
df = df[df['Price'] >= 5000]

# %% [markdown]
# Selanjutnya juga kendaraan dengan harga di bawah 5,000 SAR diidentifikasi sebagai data tidak valid karena tidak merepresentasikan harga pasar yang realistis. Nilai tersebut kemungkinan merupakan input error atau data corrupt dari proses pengumpulan data, sehingga perlu difilter sebelum analisis lebih lanjut.

# %%
# data pada kolom Make dan Type
df[["Make","Type"]].value_counts().sort_index()
# Out:
# Make          Type
# Ashok         Leyland     2
# Aston Martin  DB9         1
#               Vanquish    1
#               Vantage     2
# Audi          A3          4
#                          ..
# Volvo         FH          1
#               XC90        1
# Zhengzhou     Pick up     2
# Škoda         Fabia       1
#               Superb      1
# Name: count, Length: 409, dtype: int64

# %%
# data dengan nilai "Other" pada kolom Type
df[df["Type"] == "Other"]
# Out:
#             Make   Type  Year       Origin          Color    Options  \
# 1157        Ford  Other  1982        Other         Bronze       Full
# 1280  Mitsubishi  Other  2006        Saudi          White   Standard
# 1497       Honda  Other  2009        Saudi         Orange       Full
# 2898       Honda  Other  2011        Saudi          Black   Standard
# 3078       Other  Other  2019        Other          White       Full
# 3209        Ford  Other  2013  Gulf Arabic           Blue  Semi Full
# 3989       Geely  Other  2017        Saudi           Blue       Full
# 4007     Hyundai  Other  2012        Saudi          Black       Full
# 4237        Ford  Other  2016        Saudi  Another Color       Full
# 4238        Ford  Other  1963        Saudi           Blue   Standard
# 4419         GMC  Other  2006        Other          Black       Full
# 4730     Hyundai  Other  2011        Other          Black       Full
# 4800       Other  Other  2009        Other         Orange   Standard
# ...

# %%
# data dengan nilai "Other" pada kolom Make
summary = pd.DataFrame({
    "Column": ["Type", "Make"],
    "Other_Count": [
        (df["Type"] == "Other").sum(),
        (df["Make"] == "Other").sum()
    ],
    "Other_Percentage": [
        (df["Type"] == "Other").mean() * 100,
        (df["Make"] == "Other").mean() * 100
    ]
})

summary
# Out:
#   Column  Other_Count  Other_Percentage
# 0   Type           22          0.397184
# 1   Make            7          0.126377

# %% [markdown]
# Kategori ‘Other’ hanya merepresentasikan kurang dari 0.5% data sehingga tidak memberikan kontribusi signifikan terhadap pola harga dan berpotensi menambah noise

# %%
# Drop data dengan nilai "Other" pada kolom Make dan Type
df = df[(df["Make"] != "Other") & (df["Type"] != "Other")]

# %% [markdown]
# Disini saya menghapus baris dengan nilai “Other” pada kolom Type karena tidak merepresentasikan tipe mobil yang spesifik dan jumlahnya sangat kecil, sehingga berpotensi menambah noise pada model.

# %%
# Informasi dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5517 entries, 0 to 8246
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         5517 non-null   object
#  1   Type         5517 non-null   object
#  2   Year         5517 non-null   int64
#  3   Origin       5491 non-null   object
#  4   Color        5517 non-null   object
#  5   Options      5478 non-null   object
#  6   Engine_Size  4322 non-null   float64
#  7   Fuel_Type    5517 non-null   object
#  8   Gear_Type    5499 non-null   object
#  9   Mileage      5517 non-null   int64
#  10  Region       5517 non-null   object
#  11  Price        5517 non-null   int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 560.3+ KB

# %%
# Cek jumlah missing value setelah data cleaning
df.isnull().sum()
# Out:
# Make              0
# Type              0
# Year              0
# Origin           26
# Color             0
# Options          39
# Engine_Size    1195
# Fuel_Type         0
# Gear_Type        18
# Mileage           0
# Region            0
# Price             0
# dtype: int64

# %%
# Drop data dengan nilai missing pada kolom Origin dan Options
df = df.dropna(subset=["Origin", "Options"])

# %% [markdown]
# Missing value pada kolom Origin dan Options dihapus karena sangat sedikit dan tidak terlalu berpengaruh untuk analisis dan modeling nanti.

# %%
# mengisi missing value pada kolom Engine_Size dengan median berdasarkan kelompok Make dan Type
df["Engine_Size"] = df.groupby(["Make", "Type"])["Engine_Size"].transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# Nilai kosong pada kolom Engine_Size diisi menggunakan median berdasarkan kombinasi Make dan Type mobil yang sama. Pendekatan ini dipilih karena kapasitas mesin cenderung serupa pada mobil dengan merek dan tipe yang sama, sehingga imputasi menjadi lebih representatif dibanding menggunakan median keseluruhan.

# %%
df.head()
# Out:
#        Make     Type  Year Origin   Color    Options  Engine_Size Fuel_Type  \
# 0  Chrysler     C300  2018  Saudi   Black       Full          5.7       Gas
# 2    Nissan    Sunny  2019  Saudi  Silver   Standard          1.5       Gas
# 3   Hyundai  Elantra  2019  Saudi    Grey   Standard          1.6       Gas
# 4   Hyundai  Elantra  2019  Saudi  Silver  Semi Full          2.0       Gas
# 5     Honda   Accord  2018  Saudi    Navy       Full          1.5       Gas
#
#    Gear_Type  Mileage  Region   Price
# 0  Automatic   103000  Riyadh  114000
# 2  Automatic    72418  Riyadh   27500
# 3  Automatic   114154  Riyadh   43000
# 4  Automatic    41912  Riyadh   59500
# 5  Automatic    39000  Riyadh   72000

# %%
# Cek jumlah missing value setelah data cleaning
df.isnull().sum()
# Out:
# Make            0
# Type            0
# Year            0
# Origin          0
# Color           0
# Options         0
# Engine_Size    52
# Fuel_Type       0
# Gear_Type       0
# Mileage         0
# Region          0
# Price           0
# dtype: int64

# %%
# Drop data dengan nilai missing pada kolom Engine_Size
df = df.dropna(subset=["Engine_Size"])

# %% [markdown]
# Sisa missing value pada Engine_Size hanya 52 baris (proporsi kecil), sehingga dipilih untuk di-drop agar tidak menimbulkan bias dari imputasi tambahan dan menjaga kualitas data untuk modeling.

# %%
# Cek jumlah missing value setelah data cleaning
df.isnull().sum()
# Out:
# Make           0
# Type           0
# Year           0
# Origin         0
# Color          0
# Options        0
# Engine_Size    0
# Fuel_Type      0
# Gear_Type      0
# Mileage        0
# Region         0
# Price          0
# dtype: int64

# %%
# Tampilkan data dengan nilai "Other" dan "Classic" pada kolom Make
df[df["Make"].isin(["Other", "Classic"])]
# Out:
#          Make         Type  Year Origin          Color Options  Engine_Size  \
# 2697  Classic     Cadillac  1995  Saudi            Red    Full          8.0
# 5506  Classic  Mini Cooper  1972  Other  Another Color    Full          1.3
#
#      Fuel_Type  Gear_Type  Mileage  Region  Price
# 2697       Gas  Automatic      119  Riyadh  25000
# 5506       Gas     Manual     1000  Dammam  42000

# %%
# Drop data dengan nilai "Other" dan "Classic" pada kolom Make
df = df[(df["Make"] != "Other") & (df["Make"] != "Classic")]

# %% [markdown]
# Value "Classic" pada kolom Make tidak merepresentasikan brand mobil yang sebenarnya yang seharusnya Cadillac dan Mini Cooper itu merknya dan hanya berjumlah 2 baris (<0.05%). Untuk menjaga konsistensi kategorikal, baris tersebut dihapus.

# %%
# shape dataset setelah data cleaning
df.shape
# Out:
# (5417, 12)

# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5417 entries, 0 to 8246
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         5417 non-null   object
#  1   Type         5417 non-null   object
#  2   Year         5417 non-null   int64
#  3   Origin       5417 non-null   object
#  4   Color        5417 non-null   object
#  5   Options      5417 non-null   object
#  6   Engine_Size  5417 non-null   float64
#  7   Fuel_Type    5417 non-null   object
#  8   Gear_Type    5417 non-null   object
#  9   Mileage      5417 non-null   int64
#  10  Region       5417 non-null   object
#  11  Price        5417 non-null   int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 550.2+ KB

# %%
# Deskripsi statistik untuk kolom kategorikal
df.describe(include=["object"])
# Out:
#           Make    Type Origin  Color Options Fuel_Type  Gear_Type  Region
# count     5417    5417   5417   5417    5417      5417       5417    5417
# unique      55     347      3     15       3         3          2      27
# top     Toyota  Accent  Saudi  White    Full       Gas  Automatic  Riyadh
# freq      1246     210   4082   2285    2070      5322       4852    2285

# %%
# Deskripsi statistik untuk kolom numerik
df.describe()
# Out:
#               Year  Engine_Size       Mileage         Price
# count  5417.000000  5417.000000  5.417000e+03  5.417000e+03
# mean   2014.829057     3.191324  1.411476e+05  7.950538e+04
# std       4.991642     1.463403  3.398515e+05  7.426179e+04
# min    1964.000000     1.000000  1.000000e+02  5.000000e+03
# 25%    2013.000000     2.000000  4.800400e+04  3.600000e+04
# 50%    2016.000000     2.700000  1.020000e+05  5.900000e+04
# 75%    2018.000000     4.000000  1.820000e+05  9.500000e+04
# max    2021.000000     9.000000  2.000000e+07  1.150000e+06

# %% [markdown]
# 1. Pada kolom year memiliki min tahun 1964 yang artinya ada mobil klasik dan masih masuk akal secara bisnis sehingga tidak dilakukan drop
# 2. Engine_Size memiliki max 9.0L atau 9000cc masih masuk akal untuk mobil besar seperti SUV atau Muscle Car sehingga tidak perlu dihapus
# 3. Pada Mileage memiliki outlier pada max yaitu 20.000.000 km yang mana secara logika tidak mungkin untuk mobil sampai 20.000.000 km kemungkinan besar ada kesalahan ketik. Maka outlier tersebut harus kita drop
# 4. Price memiliki distribusi right-skewed yang mana sebagian besar mobil memiliki rentang harga menengah dan sedikit yang tinggi. Memiliki nilai max 1.150.000 SAR yang masih masuk akal untuk mobil mewah sehingga tidak dianggap anomali

# %% [markdown]
# #### **Distribusi Feature Numerikal**

# %%
plt.figure(figsize=(5, 4))
plt.hist(df["Year"], bins=30, edgecolor='black')
plt.title("Distribution of Car Years")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# Pada distribusi tahun pembuatan mobil dapat dilihat memiliki grafik left-skewed dan tahun mobil terkonsentrasi di rentang tahun 2010–2020 dan juga puncak grafik (modus) terlihat sangat jelas berada di rentang tersebut, terutama antara tahun 2015 hingga 2018 di mana jumlah mobil mencapai titik tertinggi (di atas 1400 unit). Artinya ini menunjukkan bahwa data tersebut didominasi oleh mobil-mobil muda/relatif baru. Mobil dengan tahun pembuatan di bawah 2000 jumlahnya sangat sedikit (langka) dalam dataset ini.

# %%
plt.figure(figsize=(5, 4))
plt.hist(df["Engine_Size"], bins=30, edgecolor='black')
plt.title("Distribution of Engine Sizes")
plt.xlabel("Engine Size")
plt.show()

# %% [markdown]
# Distribusi ukuran mesin bersifat right-skewed dan multimodal, di mana mayoritas mobil memiliki kapasitas mesin antara 1.0 hingga 4.0. Ukuran mesin yang paling dominan adalah 2.5 dan 3.5, sementara mobil dengan mesin di atas 6.0 sangat jarang ditemukan.

# %%
plt.figure(figsize=(5, 4))
plt.boxplot(df["Mileage"])
plt.title("Distribution of Car Mileage")
plt.ylabel("Mileage")
plt.show()

# %% [markdown]
# Visualisasi Car Mileage saat ini tidak informatif dikarenakan adanya extreme outlier pada angka 20.000.000 km yang menarik skala sumbu Y terlalu jauh ke atas. Data ini terindikasi kuat sebagai data eror dan harus dibersihkan agar distribusi jarak tempuh mobil yang sebenarnya dapat terlihat dengan jelas.

# %%
# Menghitung IQR untuk kolom Mileage dan menghapus outlier berdasarkan IQR
Q1 = df["Mileage"].quantile(0.25)
Q3 = df["Mileage"].quantile(0.75)
IQR = Q3 - Q1

upper_bound = Q3 + 1.5 * IQR

df = df[df["Mileage"] <= upper_bound]

# %% [markdown]
# Selanjutnya kita akan menghapus outlier tersebut menggunakan metode Interquartile Range (IQR) untuk menentukan rentang jarak tempuh yang dianggap wajar. Alasan utama penggunaan metode IQR adalah karena sifatnya yang robust terhadap outlier. Tidak seperti nilai rata-rata (mean) yang akan bergeser jauh akibat angka 20.000.000 km, IQR hanya berfokus pada 50% data di bagian tengah, sehingga batas pembersihan data menjadi lebih objektif dan tetap mencerminkan mayoritas populasi mobil yang sebenarnya.

# %%
plt.figure(figsize=(5, 4))
plt.boxplot(df["Mileage"])
plt.title("Distribution of Car Mileage")
plt.ylabel("Mileage")
plt.show()

# %% [markdown]
# Sekarang boxplot sudah dapat terlihat jelas distribusinya. Di sini kita menghapus outlier pada feature Mileage dengan menggunakan metode IQR dan sekarang outlier 20.000.000 km sudah hilang. Median di sekitar 100.000 km, Q1 45.000 km dan Q3 165.000 yang artinya 50% mobil berada di rentang itu. Ada juga nilai yang di atas 350.000 km tapi masih realistis untuk mobil tua yang kmnya sudah banyak sehingga tidak dihapus.

# %%
from matplotlib.ticker import FuncFormatter

# Fungsi untuk mengubah format angka
def thousands(x, pos):
    return f'{x*1e-3:g}K' 

formatter = FuncFormatter(thousands)

plt.figure(figsize=(5, 4))
plt.hist(df["Price"], bins=30, edgecolor='black')

# Menerapkan formatter ke sumbu X
plt.gca().xaxis.set_major_formatter(formatter)

plt.title("Distribution of Car Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
from matplotlib.ticker import FuncFormatter

# Formatter untuk mengubah angka ke ribuan (K)
formatter = FuncFormatter(lambda x, pos: f'{x*1e-3:g}K')

plt.figure(figsize=(8, 4))
sns.boxplot(x=df["Price"], color='skyblue')

# Terapkan formatter ke sumbu X
plt.gca().xaxis.set_major_formatter(formatter)

plt.title("Distribution of Car Prices (with Outliers)")
plt.xlabel("Price (in Thousands)")
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# Pada grafik distribusi Price dapat dilihat bahwa memiliki pola right-skewed yang artinya feature Price sebagian besar mobil harganya di rentang rendah hingga menengah, sementara hanya sebagian kecil mobil yang memiliki harga sangat tinggi yang dianggap outlier. namun masih masuk akal untuk mobil mewah

# %% [markdown]
# #### **Distribusi Feature Kategorikal**

# %%
# top 10 mobil terbanyak berdasarkan Make
top_10_makes = df["Make"].value_counts().head(10)

plt.figure(figsize=(5, 4))
plt.bar(top_10_makes.index, top_10_makes.values)

plt.title("Top 10 Cars by Make")
plt.xlabel("Make")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Distribusi Make atau merknya menunjukkan Toyota sebagai brand paling dominan dengan lebih dari 1.200 listing, jauh di atas brand lain. Hyundai dan Ford berada di posisi berikutnya dengan jumlah signifikan namun terpaut cukup jauh. Hal ini menunjukkan pasar mobil bekas di platform didominasi oleh brand mass-market yang dikenal memiliki resale value stabil dan permintaan tinggi

# %%
plt.figure(figsize=(5, 4))
plt.bar(df["Options"].value_counts().index, df["Options"].value_counts().values)
plt.title("Count of Cars by Options")
plt.xlabel("Options")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Mayoritas mobil di listing didominasi mobil dengan Full options atau dengan fitur yang paling lengkap dengan jumlah mencapai 2.000 unit. Selanjutnya kedua disusul oleh mobil bertipe standard jumlahnya sedikit di bawah 2.000 unit. Lalu semi full di sekitar 1.400 unit. Dominasi tipe Full di sini bisa mengindikasikan bahwa data ini diambil dari segmen mobil menengah ke atas atau pasar di mana pembeli sangat mementingkan kelengkapan fitur.

# %%
plt.figure(figsize=(5, 4))
plt.bar(df["Origin"].value_counts().index, df["Origin"].value_counts().values)
plt.title("Count of Cars by Origin")
plt.xlabel("Origin")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Pada grafik distribusi Origin atau asal mobil tersebut didominasi oleh Saudi yang hampir menyentuh 4.000 listing. Ini sangan kontras dibanding lainnya. Selanjutnya posisi kedua mobil dari Gulf Arabic (negara teluk-teluk lainnya) yang sedikit di rentang 700 unit lalu terakhir ada mobil yang berasal dari wilayah lain atau Other di sekitar 600 unit.

# %%
plt.figure(figsize=(5, 4))
plt.bar(df["Gear_Type"].value_counts().index, df["Gear_Type"].value_counts().values)
plt.title("Count of Cars by Gear Type")
plt.xlabel("Gear Type")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Selanjutnya pada grafik distribusi Gear Type menunjukkan dominasi yang sangat kuat dari mobil bertransimisi Automatic dengan jumlah jauh melampaui 4.000 unit. Lalu ada listing mobil manual yang di rentang 500 unit. Hal ini mencerminkan tren pasar modern dan kenyamanan berkendara yang lebih mengutamakan transmisi automatic.

# %%
plt.figure(figsize=(5, 4))
plt.bar(df["Fuel_Type"].value_counts().index, df["Fuel_Type"].value_counts().values)
plt.title("Count of Cars by Fuel Type")
plt.xlabel("Fuel Type")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Grafik menunjukkan bahwa hampir seluruh listing mobil menggunakan bahan bakar Gas (Bensin), dengan jumlah yang sangat dominan menyentuh angka di atas 5.000 unit. Mobil bermesin Diesel memiliki jumlah yang sangat kecil (di bawah 200 unit), sementara mobil Hybrid hampir tidak terlihat atau berjumlah sangat sedikit dalam dataset ini.

# %%
plt.figure(figsize=(7, 4))
plt.bar(df["Color"].value_counts().index, df["Color"].value_counts().values)
plt.title("Count of Cars by Color")
plt.xlabel("Color")
plt.xticks(rotation=45)
plt.show()

# %%
top_10_regions = df["Region"].value_counts().head(10)
plt.figure(figsize=(6, 4))
plt.bar(top_10_regions.index, top_10_regions.values)    
plt.title("Top 10 Cars by Region")
plt.xlabel("Region")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### **Analisis Feature Numerikal vs Price (Target)**

# %%
plt.figure(figsize=(5,4))
plt.scatter(df["Year"], df["Price"], alpha=0.5)
plt.title("Year vs Price")
plt.xlabel("Year")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# Berdasarkan scatterplot di atas ada hubungan antara Year dan Price, di mana mobil dengan tahun produksi yang lebih baru cenderung memiliki harga lebih tinggi. Sebaliknya, mobil dengan tahun produksi lebih lama umumnya berada pada rentang harga yang lebih rendah. Pola ini menunjukkan bahwa usia kendaraan merupakan faktor penting yang memengaruhi nilai jual mobil di pasar.

# %%
plt.figure(figsize=(7, 4))
plt.scatter(df["Mileage"], df["Price"], alpha=0.5)
plt.title("Mileage vs Price")
plt.xlabel("Mileage")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# Dapat dilihat bahwa semakin rendah jarak tempuh mobil maka semakin tinggi harga dari sebuah mobil. Karena mobil yang memiliki jarak tempuh atau Mileage rendah biasanya kondisinya lebih bagus. Scatterplot di atas juga menunjukkan bahwa mileage merupakan salah satu faktor utama dalam menentukan harga, di mana penyusutan harga paling tajam terjadi saat mobil mulai melewati ambang jarak tempuh tertentu.

# %%
plt.figure(figsize=(7, 4))
plt.scatter(df["Engine_Size"], df["Price"], alpha=0.5)
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x):,}'))
plt.title("Engine Size vs Price")
plt.xlabel("Engine Size")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# Scatterplot di atas menunjukkan hubungan antara Engine_Size dengan Price. Sebagian besar kendaraan terkonsentrasi pada rentang mesin 1.0 hingga 6.0L dengan harga di bawah 200.000 SAR, meskipun terdapat beberapa outlier dengan harga ekstrem terutama pada mesin berukuran besar. Secara visual, pola hubungan antara kedua variabel ini tidak tampak jelas karena sebaran harga pada setiap ukuran mesin sangat bervariasi.

# %% [markdown]
# #### **Analisis Feature Kategorikal vs Price (Target)**

# %%
top10_make_median = df.groupby('Make')['Price'].median().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 4))
top10_make_median.sort_values().plot(kind='barh', color='steelblue')
plt.title('Top 10 Car Make by Price')
plt.xlabel('Median Price (SAR)')
plt.ylabel('Make')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.boxplot(data=df, x="Gear_Type", y="Price")
plt.title("Price by Gear Type")
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.boxplot(data=df, x="Options", y="Price")
plt.title("Price by Options Level")
plt.show()

# %% [markdown]
# ## **Korelasi Antar Feature Numerikal**

# %%
corr = df[["Year","Engine_Size","Mileage","Price"]].corr()

plt.figure(figsize=(7,7))
sns.heatmap(corr, annot=True, cmap="Blues")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Berdasarkan correlation matrix, variabel Year memiliki korelasi positif tertinggi terhadap Price (r = 0.32), artinya mobil dengan tahun produksi lebih baru cenderung lebih mahal. Engine_Size juga berkorelasi positif lemah (r = 0.32), sementara Mileage berkorelasi negatif (r = -0.28) — semakin tinggi jarak tempuh, harga cenderung lebih rendah. Secara keseluruhan, tidak ada fitur numerik yang berkorelasi kuat terhadap Price, mengindikasikan bahwa fitur kategorikal seperti Make dan Options lebih dominan dalam menentukan harga.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5235 entries, 0 to 8246
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         5235 non-null   object
#  1   Type         5235 non-null   object
#  2   Year         5235 non-null   int64
#  3   Origin       5235 non-null   object
#  4   Color        5235 non-null   object
#  5   Options      5235 non-null   object
#  6   Engine_Size  5235 non-null   float64
#  7   Fuel_Type    5235 non-null   object
#  8   Gear_Type    5235 non-null   object
#  9   Mileage      5235 non-null   int64
#  10  Region       5235 non-null   object
#  11  Price        5235 non-null   int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 531.7+ KB

# %%
df.to_csv('UsedCarsSaudiCleaned.csv',index=False)

# %% [markdown]
# ## **Data Preparation**

# %%
# Import library untuk modeling
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, KFold

import category_encoders as ce
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.compose import TransformedTargetRegressor

from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder, FunctionTransformer
from sklearn.impute import SimpleImputer

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
df = pd.read_csv('UsedCarsSaudiCleaned.csv')

# %%
df.head()
# Out:
#        Make     Type  Year Origin   Color    Options  Engine_Size Fuel_Type  \
# 0  Chrysler     C300  2018  Saudi   Black       Full          5.7       Gas
# 1    Nissan    Sunny  2019  Saudi  Silver   Standard          1.5       Gas
# 2   Hyundai  Elantra  2019  Saudi    Grey   Standard          1.6       Gas
# 3   Hyundai  Elantra  2019  Saudi  Silver  Semi Full          2.0       Gas
# 4     Honda   Accord  2018  Saudi    Navy       Full          1.5       Gas
#
#    Gear_Type  Mileage  Region   Price
# 0  Automatic   103000  Riyadh  114000
# 1  Automatic    72418  Riyadh   27500
# 2  Automatic   114154  Riyadh   43000
# 3  Automatic    41912  Riyadh   59500
# 4  Automatic    39000  Riyadh   72000

# %% [markdown]
# #### **Feature Engineering & Preprocessing Pipeline**

# %%
from datetime import datetime
# Tahun mobil
df["Car_Age"] = datetime.now().year - df["Year"]
df.drop(columns=["Year"], inplace=True)

# %% [markdown]
# Dibuat fitur baru Car_Age yang merepresentasikan usia kendaraan (tahun sekarang dikurangi tahun produksi). Fitur ini digunakan karena harga mobil lebih dipengaruhi oleh umur kendaraan dibandingkan angka tahun produksi secara langsung. Kolom Year kemudian dihapus untuk menghindari redundansi informasi.

# %%
bin_col = ["Gear_Type"]
ohe_col = ["Origin", "Color", "Options", "Fuel_Type", "Region"]
high_card_cols = ["Make", "Type"] 
num_col = ["Engine_Size", "Mileage", "Car_Age"]

# %%
numeric_pipeline = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler",  RobustScaler()),
])

binary_pipeline = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("ordinal", OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)),
])

ohe_pipeline = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("ohe", OneHotEncoder(handle_unknown="ignore", sparse_output=False)),
])

high_card_pipeline = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("binary", ce.BinaryEncoder()),
])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num",      numeric_pipeline,   num_col),
        ("bin",      binary_pipeline,    bin_col),
        ("ohe",      ohe_pipeline,       ohe_col),
        ("high_card",high_card_pipeline, high_card_cols),
    ],
    remainder='drop'
)

# %% [markdown]
# #### **Data Splitting**

# %%
X = df.drop(['Price'], axis=1)
y = df['Price']

# %%
X_train, X_test, y_train, y_test= train_test_split(
    X,
    y,  
    test_size=0.2,
    random_state=1)

# %% [markdown]
# #### **Benchmark Model**

# %%
# Define algoritma yang digunakan
lr = LinearRegression()
knn = KNeighborsRegressor()
dt = DecisionTreeRegressor(random_state=1)
rf = RandomForestRegressor(random_state=1)
xgb = XGBRegressor(random_state=1)

# Pemodelan dilakukan dalam skala logaritmik, namun kemudian di-inverse kembali untuk interpretasi
log_lr = TransformedTargetRegressor(lr, func=np.log, inverse_func=np.exp)
log_knn = TransformedTargetRegressor(knn, func=np.log, inverse_func=np.exp)
log_dt = TransformedTargetRegressor(dt, func=np.log, inverse_func=np.exp)
log_rf = TransformedTargetRegressor(rf, func=np.log, inverse_func=np.exp)
log_xgb = TransformedTargetRegressor(xgb, func=np.log, inverse_func=np.exp)


# Kandidat algoritma
model_names = ['Linear Regression', 'KNN Regressor', 'DecisionTree Regressor', 'RandomForest Regressor', 'XGBRegressor']
models = [log_lr, log_knn, log_dt, log_rf, log_xgb]

nilai_mean_rmse, nilai_std_rmse = [], []
nilai_mean_mae,  nilai_std_mae  = [], []
nilai_mean_mape, nilai_std_mape = [], []
nilai_mean_r2, nilai_std_r2 = [], []

# Mencari algoritma terbaik berdasarkan tiap metrics
for name, model in zip(model_names, models):

    crossval = KFold(n_splits=5, shuffle=True, random_state=1)

    estimator = Pipeline([
        ('preprocessing', preprocessor),
        ('model', model)
    ])

    cv_rmse = cross_val_score(estimator, X_train, y_train, cv=crossval,
                                scoring='neg_root_mean_squared_error', error_score='raise')
    cv_mae  = cross_val_score(estimator, X_train, y_train, cv=crossval,
                                scoring='neg_mean_absolute_error', error_score='raise')
    cv_mape = cross_val_score(estimator, X_train, y_train, cv=crossval,
                                scoring='neg_mean_absolute_percentage_error', error_score='raise')
    cv_r2 = cross_val_score(estimator, X_train, y_train, cv=crossval,
                                scoring='r2', error_score='raise')

    nilai_mean_rmse.append(abs(cv_rmse.mean()))
    nilai_std_rmse.append(cv_rmse.std())
    nilai_mean_mae.append(abs(cv_mae.mean()))
    nilai_std_mae.append(cv_mae.std())
    nilai_mean_mape.append(abs(cv_mape.mean()))
    nilai_std_mape.append(cv_mape.std())
    nilai_mean_r2.append(cv_r2.mean())    
    nilai_std_r2.append(cv_r2.std())

    print(f"  {name}: RMSE={abs(cv_rmse.mean()):,.2f} (±{cv_rmse.std():,.2f}) | "
      f"MAE={abs(cv_mae.mean()):,.2f} (±{cv_mae.std():,.2f}) | "
      f"MAPE={abs(cv_mape.mean()):.4f} (±{cv_mape.std():.4f}) | "
      f"R²={cv_r2.mean():.4f} (±{cv_r2.std():.4f})")

cv_results = pd.DataFrame({
    'Model'    : model_names,
    'Mean_RMSE': nilai_mean_rmse,
    'Std_RMSE' : nilai_std_rmse,
    'Mean_MAE' : nilai_mean_mae,
    'Std_MAE'  : nilai_std_mae,
    'Mean_MAPE': nilai_mean_mape,
    'Std_MAPE' : nilai_std_mape,
    'Mean_R2': nilai_mean_r2,
    'Std_R2' : nilai_std_r2,
})
# Out:
#   Linear Regression: RMSE=49,866.27 (±4,280.20) | MAE=27,018.26 (±1,334.77) | MAPE=0.3687 (±0.0293) | R²=0.5147 (±0.0387)
#   KNN Regressor: RMSE=38,730.30 (±5,765.33) | MAE=19,054.40 (±1,064.52) | MAPE=0.2852 (±0.0195) | R²=0.7064 (±0.0580)
#   DecisionTree Regressor: RMSE=58,847.85 (±6,858.06) | MAE=26,051.10 (±2,175.22) | MAPE=0.3799 (±0.0454) | R²=0.3169 (±0.1316)
#   RandomForest Regressor: RMSE=39,085.56 (±4,382.99) | MAE=17,661.08 (±668.18) | MAPE=0.2304 (±0.0121) | R²=0.7007 (±0.0469)
#   XGBRegressor: RMSE=35,848.52 (±5,600.64) | MAE=16,273.89 (±789.10) | MAPE=0.2158 (±0.0131) | R²=0.7461 (±0.0636)

# %%
cv_results
# Out:
#                     Model     Mean_RMSE     Std_RMSE      Mean_MAE  \
# 0       Linear Regression  49866.267811  4280.204369  27018.255013
# 1           KNN Regressor  38730.303853  5765.330637  19054.398851
# 2  DecisionTree Regressor  58847.853631  6858.062842  26051.096226
# 3  RandomForest Regressor  39085.557579  4382.986508  17661.076627
# 4            XGBRegressor  35848.524609  5600.640661  16273.891016
#
#        Std_MAE  Mean_MAPE  Std_MAPE   Mean_R2    Std_R2
# 0  1334.765330   0.368665  0.029330  0.514746  0.038735
# 1  1064.520060   0.285236  0.019494  0.706392  0.058046
# 2  2175.219652   0.379865  0.045371  0.316940  0.131613
# 3   668.176412   0.230372  0.012142  0.700682  0.046852
# 4   789.103760   0.215765  0.013115  0.746081  0.063639

# %% [markdown]
# Berdasarkan hasil uji coba terhadap lima algoritma regresi, XGBRegressor dan RandomForest Regressor terpilih sebagai dua model dengan performa terbaik. XGBRegressor menjadi yang utama karena mencatatkan nilai rata-rata R2 tertinggi sebesar 0,746, serta tingkat kesalahan rata-rata (MAE) terendah di angka 17.661. Sementara itu, RandomForest dipilih sebagai model pembanding yang solid dengan tingkat stabilitas prediksi yang tinggi (ditandai dengan nilai standar deviasi yang rendah).

# %% [markdown]
# #### **Predict Test Set dengan 2 Benchmark Model**

# %%
# Benchmark 2 model terbaik
models = {
    'XGB': TransformedTargetRegressor(XGBRegressor(random_state=1), func=np.log, inverse_func=np.exp),
    'RandomForest': TransformedTargetRegressor(RandomForestRegressor(random_state=1), func=np.log, inverse_func=np.exp)
}

score_rmse, score_mae, score_mape, score_r2 = [], [], [], []

# Prediksi pada test set
for name, model in models.items():
    pipeline = Pipeline([
        ('preprocessing', preprocessor),
        ('model', model)
    ])
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    
    if name == 'XGB':
        y_pred_xgb_before_tuning = y_pred

    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae  = mean_absolute_error(y_test, y_pred)
    mape = mean_absolute_percentage_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    score_rmse.append(rmse)
    score_mae.append(mae)
    score_mape.append(mape)
    score_r2.append(r2)

    print(f"  {name}: RMSE={rmse:,.2f} | MAE={mae:,.2f} | MAPE={mape:.4f} | R²={r2:.4f}")

score_before_tuning = pd.DataFrame(
    {'RMSE': score_rmse, 'MAE': score_mae, 'MAPE': score_mape, 'R2': score_r2},
    index=models.keys()
)
# Out:
#   XGB: RMSE=40,872.53 | MAE=16,371.85 | MAPE=0.2026 | R²=0.7716
#   RandomForest: RMSE=48,581.25 | MAE=18,288.02 | MAPE=0.2206 | R²=0.6773

# %%
score_before_tuning
# Out:
#                       RMSE           MAE      MAPE        R2
# XGB           40872.528476  16371.847656  0.202571  0.771605
# RandomForest  48581.252982  18288.024179  0.220621  0.677329

# %% [markdown]
# - RMSE & MAE lebih rendah yang artinya Error prediksi XGB lebih kecil.
# - MAPE 20.2% artinya rata-rata kesalahan prediksi sekitar 20% dari harga asli.
# - R² 0.77 artinya 77% variasi harga dapat dijelaskan oleh model.

# %% [markdown]
# #### **Hyperparameter Tuning**
#
# Karena model XGBoost memiliki performa yang sedikit lebih baik dari RandomForest, maka selanjutnya kita akan menggunakan model XGBoost ini sebagai model akhir. Pada tahap ini, kita akan melakukan hyperparameter tuning pada model XGBoost dengan harapan dapat meningkatkan performa model.

# %%
# Hyperparam space XGboost
hyperparam_space_xgb = {
    'model__regressor__max_depth'        : [2, 3, 4],
    'model__regressor__learning_rate'    : [0.01, 0.05, 0.1],
    'model__regressor__n_estimators'     : list(np.arange(200, 501)),
    'model__regressor__subsample'        : [0.6, 0.7, 0.8],
    'model__regressor__gamma'            : [1, 2, 5, 10],
    'model__regressor__colsample_bytree' : [0.5, 0.6, 0.7],
    'model__regressor__reg_alpha'        : [1.0, 5.0, 10.0],
    'model__regressor__reg_lambda'       : [5.0, 10.0, 20.0],
    'model__regressor__min_child_weight' : [5, 10, 20],
}

# %%
# Benchmark model dengan hyperparameter tuning
xgb = XGBRegressor(random_state=1, verbosity=0)

log_xgb_tuning = TransformedTargetRegressor(
    xgb, func=np.log, inverse_func=np.exp
)

# Membuat algorithm chains
estimator_xgb = Pipeline([
        ('preprocessing', preprocessor),
        ('model', log_xgb_tuning)
        ])

crossval = KFold(n_splits=5, shuffle=True, random_state=1)

# Hyperparameter tuning
random_xgb = RandomizedSearchCV(
    estimator_xgb,
    param_distributions=hyperparam_space_xgb,
    n_iter=100,
    cv=crossval,
    scoring=[
        'neg_root_mean_squared_error',
        'neg_mean_absolute_error',
        'neg_mean_absolute_percentage_error',
        'r2',
    ],
    n_jobs=-1,
    refit='neg_mean_absolute_percentage_error',    # ← changed back from RMSE
    random_state=1
)

# %%
# Fitting data training untuk mencari parameter terbaik
random_xgb.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(transformers=[('num',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('scaler',
#                                                                                                 RobustScaler())]),
#                                                                                ['Engine_Size',
#                                                                                 'Mileage',
#                                                                                 'Car_Age']),
# ...

# %%
# Melihat hasil tuning dalam bentuk dataframe. Diurutkan berdasarkan RMSE, MAE & MAPE
pd.DataFrame(random_xgb.cv_results_).sort_values(by=['rank_test_neg_root_mean_squared_error', 'rank_test_neg_mean_absolute_error', 'rank_test_neg_mean_absolute_percentage_error']).head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 20       0.558617      0.020231         0.049608        0.011386
# 0        0.506509      0.025997         0.055638        0.010978
# 13       0.558850      0.051946         0.063195        0.029003
# 61       0.551030      0.099133         0.049682        0.004198
# 71       0.424359      0.075057         0.045529        0.003704
#
#     param_model__regressor__subsample  param_model__regressor__reg_lambda  \
# 20                                0.6                                 5.0
# 0                                 0.6                                10.0
# 13                                0.6                                 5.0
# 61                                0.8                                10.0
# 71                                0.7                                10.0
#
#     param_model__regressor__reg_alpha  param_model__regressor__n_estimators  \
# ...

# %%
# Cek skor dan params terbaik
print('XGBoost')
print('Best_score:', random_xgb.best_score_)
print('Best_params:', random_xgb.best_params_)
# Out:
# XGBoost
# Best_score: -0.2549804836511612
# Best_params: {'model__regressor__subsample': 0.6, 'model__regressor__reg_lambda': 5.0, 'model__regressor__reg_alpha': 1.0, 'model__regressor__n_estimators': np.int64(435), 'model__regressor__min_child_weight': 5, 'model__regressor__max_depth': 4, 'model__regressor__learning_rate': 0.05, 'model__regressor__gamma': 1, 'model__regressor__colsample_bytree': 0.6}

# %% [markdown]
# #### **Predict ke Test Set dengan Tuned Model**
#
# Melakukan prediksi pada test set dengan menggunakan model XGBoost dan hyperparameter terpilih.

# %%
# Model XGBoost
model = {'XGB': XGBRegressor(random_state=1)}

# Define model terhadap estimator terbaik
xgb_tuning = random_xgb.best_estimator_

# Predict test set
y_pred_xgb_tuning = xgb_tuning.predict(X_test)

# Simpan nilai metrics RMSE, MAE & MAPE setelah tuning
rmse_xgb_tuning = np.sqrt(mean_squared_error(y_test, y_pred_xgb_tuning))
mae_xgb_tuning = mean_absolute_error(y_test, y_pred_xgb_tuning)
mape_xgb_tuning = mean_absolute_percentage_error(y_test, y_pred_xgb_tuning)
r2_xgb_tuning   = r2_score(y_test, y_pred_xgb_tuning)

score_after_tuning = pd.DataFrame(
    {'RMSE': rmse_xgb_tuning, 'MAE': mae_xgb_tuning,
     'MAPE': mape_xgb_tuning, 'R2': r2_xgb_tuning},
    index=model.keys()
)

# %%
# Mengambil baris XGB dari sebelum tuning 
before = pd.DataFrame(score_before_tuning.loc['XGB']).T
before.index = ['Before Tuning']

# Mengambil baris XGB dari sesudah tuning 
after = pd.DataFrame(score_after_tuning.loc['XGB']).T
after.index = ['After Tuning']

comparison_df = pd.concat([before, after])
display(comparison_df)
# Out:
#                        RMSE           MAE      MAPE        R2
# Before Tuning  40872.528476  16371.847656  0.202571  0.771605
# After Tuning   53279.041433  22257.318359  0.258030  0.611907

# %% [markdown]
# #### **Validation using Train & Test**

# %%
# Rebuild Pipeline untuk model XGB Sebelum Tuning
xgb_before = Pipeline([
    ('preprocessing', preprocessor),
    ('model', TransformedTargetRegressor(
        XGBRegressor(random_state=1), func=np.log, inverse_func=np.exp))
])
xgb_before.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['Engine_Size', 'Mileage',
#                                                    'Car_Age']),
#                                                  ('bin',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ordinal',
# ...

# %%
# Validation menggunakan Train vs Test Score (Before Tuning)
xgb = xgb_before['model']

y_pred_train = xgb_before.predict(X_train)
y_pred_test  = xgb_before.predict(X_test)

train_rmse = np.sqrt(mean_squared_error(y_train, y_pred_train))
test_rmse  = np.sqrt(mean_squared_error(y_test,  y_pred_test))

train_mae  = mean_absolute_error(y_train, y_pred_train)
test_mae   = mean_absolute_error(y_test,  y_pred_test)

train_mape = mean_absolute_percentage_error(y_train, y_pred_train)
test_mape  = mean_absolute_percentage_error(y_test,  y_pred_test)

train_r2   = r2_score(y_train, y_pred_train)
test_r2    = r2_score(y_test,  y_pred_test)

comparison = pd.DataFrame({
    'Train': [train_rmse, train_mae, train_mape, train_r2],
    'Test' : [test_rmse,  test_mae,  test_mape,  test_r2],
}, index=['RMSE', 'MAE', 'MAPE', 'R2'])

comparison['Gap (%)'] = ((comparison['Test'] - comparison['Train']) 
                          / comparison['Train'].abs() * 100).round(2)

print("── Train vs Test Score Comparison ──")
print(comparison.to_string())
print("\nInterpretation:")
print(f"  RMSE gap : {comparison.loc['RMSE', 'Gap (%)']:+.2f}%")
print(f"  MAE gap : {comparison.loc['MAE', 'Gap (%)']:+.2f}%")
print(f"  MAPE gap : {comparison.loc['MAPE', 'Gap (%)']:+.2f}%")
print(f"  R2 gap   : {comparison.loc['R2',   'Gap (%)']:+.2f}%")
# Out:
# ── Train vs Test Score Comparison ──
#              Train          Test  Gap (%)
# RMSE  10787.850203  40872.528476   278.88
# MAE    5959.274902  16371.847656   174.73
# MAPE      0.072519      0.202571   179.33
# R2        0.977384      0.771605   -21.05
#
# Interpretation:
#   RMSE gap : +278.88%
#   MAE gap : +174.73%
#   MAPE gap : +179.33%
#   R2 gap   : -21.05%

# %%
# Validation menggunakan Train vs Test Score (After Tuning)
y_pred_train = xgb_tuning.predict(X_train)
y_pred_test  = xgb_tuning.predict(X_test)

train_rmse = np.sqrt(mean_squared_error(y_train, y_pred_train))
test_rmse  = np.sqrt(mean_squared_error(y_test,  y_pred_test))

train_mae  = mean_absolute_error(y_train, y_pred_train)
test_mae   = mean_absolute_error(y_test,  y_pred_test)

train_mape = mean_absolute_percentage_error(y_train, y_pred_train)
test_mape  = mean_absolute_percentage_error(y_test,  y_pred_test)

train_r2   = r2_score(y_train, y_pred_train)
test_r2    = r2_score(y_test,  y_pred_test)

comparison = pd.DataFrame({
    'Train': [train_rmse, train_mae, train_mape, train_r2],
    'Test' : [test_rmse,  test_mae,  test_mape,  test_r2],
}, index=['RMSE', 'MAE', 'MAPE', 'R2'])

comparison['Gap (%)'] = ((comparison['Test'] - comparison['Train']) 
                          / comparison['Train'].abs() * 100).round(2)

print("── Train vs Test Score Comparison ──")
print(comparison.to_string())
print("\nInterpretation:")
print(f"  RMSE gap : {comparison.loc['RMSE', 'Gap (%)']:+.2f}%")
print(f"  MAE gap : {comparison.loc['MAE', 'Gap (%)']:+.2f}%")
print(f"  MAPE gap : {comparison.loc['MAPE', 'Gap (%)']:+.2f}%")
print(f"  R2 gap   : {comparison.loc['R2',   'Gap (%)']:+.2f}%")
# Out:
# ── Train vs Test Score Comparison ──
#              Train          Test  Gap (%)
# RMSE  40570.210943  53279.041433    31.33
# MAE   18961.041016  22257.318359    17.38
# MAPE      0.231758      0.258030    11.34
# R2        0.680140      0.611907   -10.03
#
# Interpretation:
#   RMSE gap : +31.33%
#   MAE gap : +17.38%
#   MAPE gap : +11.34%
#   R2 gap   : -10.03%

# %% [markdown]
# Model Pilihan XGB After Tuning. Meskipun XGB before tuning scorenya lebih bagus, tetapi setelah di validasi menggunakan train-test score, XGB After memiliki persentase gap yang lebih kecil. Sebelum tuning, model terindikasi mengalami overfitting berat dengan selisih kesalahan (gap) antar data train dan test yang mencapai lebih dari 170%. Setelah tuning, selisih tersebut berhasil ditekan hingga di bawah 50% untuk MAE dan MAPE, yang berarti model kini memiliki kemampuan generalisasi yang jauh lebih baik untuk memprediksi harga mobil di luar dataset latihan.

# %% [markdown]
# Hasil model pilihan (XGBRegressor after tuning) masih overfitting dikarenakan Type mobil yang sangat banyak, akan tetapi overfitting yang terjadi berbanding jauh dari model sebelum dilakukan tuning.
#
# Hal yang mungkin dapat mempermudah prediksi model:
# - Ada parameter untuk pemisah antara mobil umum dan mobil luxury, model saat ini memprediksi kedua tipe.
# - Ada parameter untuk detail kondisi mobil sebelum penjualan, sejauh ini kondisi hanya "Used" (yang sebelumnya di drop)

# %% [markdown]
# #### Actual vs Prediction Price Plot

# %%
fig, ax = plt.subplots(figsize=(14, 8))

sns.scatterplot(x=y_test, y=y_pred_xgb_tuning, ax=ax)

ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x):,}'))
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x):,}'))

ax.set_title('Actual vs. Predicted Price (XGB — After Tuning)')
ax.set_xlabel('Actual Price (SAR)')
ax.set_ylabel('Predicted Price (SAR)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Feature Importances**

# %% [markdown]
# Untuk dapat mengetahui sebenarnya fitur apa saja yang sangat memengaruhi target (price), kita dapat mengeceknya melalui function feature_importances.

# %%
xgb_model  = xgb_tuning['model'].regressor_

# Ambil nama fitur dari encoder
num_features  = num_col
bin_features  = bin_col
ohe_features  = (preprocessor.named_transformers_['ohe']['ohe'].get_feature_names_out(ohe_col).tolist())

sample         = X_train.iloc[:1]
full_transform = preprocessor.transform(sample)

binary_encoder  = preprocessor.named_transformers_['high_card']['binary']
high_card_features = [f'highcard_{col}' 
                      for col in binary_encoder.get_feature_names_out()]

all_feature_names = (num_features + bin_features + ohe_features + high_card_features)

feature_imp = pd.Series(
    xgb_model.feature_importances_,
    index=all_feature_names
).sort_values(ascending=True).tail(10)

plt.figure(figsize=(10, 7))
feature_imp.plot(kind='barh', color='steelblue')
plt.title('Top 10 Feature Importances (XGB — After Tuning)', fontsize=14)
plt.xlabel('Importance Score')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan grafik, dua fitur teratas memiliki importance score yang jauh melampaui fitur lainnya:
# 1. Options_Full: Menjadi fitur paling berpengaruh. Ini sangat logis dengan temuan EDA kita sebelumnya bahwa mayoritas listing adalah mobil bertipe Full options. Di pasaran, kelengkapan fitur adalah pembeda utama antara mobil murah dan mobil mahal.
#
# 2. Car_Age: Menempati posisi kedua. Hal ini membuktikan bahwa langkah membuat fitur usia mobil pda feature engineering sangat krusial. Penyusutan nilai mobil secara langsung ditentukan oleh seberapa lama mobil tersebut telah digunakan.
#
# 3. Engine_Size: Kapasitas mesin berada di urutan ketiga. Ini memvalidasi grafik distribusi mesin pada EDA sebelumnya, dimana ukuran mesin seperti 2.5L atau 3.5L menjadi faktor penentu harga yang signifikan.
#
# 4. Mileage: Meskipun penting, jarak tempuh atau mileage berada di bawah ukuran mesin. Ini menarik, karena menunjukkan bahwa di pasar ini, pembeli mungkin lebih peduli pada apa yang ada di bawah kap mesin dan kelengkapan fitur daripada sekadar angka di odometer.
#
# 5. Region_Dammam: Muncul sebagai salah satu lokasi yang memberikan pengaruh terhadap harga. Ini menandakan adanya variasi harga berdasarkan lokasi geografis di Arab Saudi.
#
# 6. Options_Standard: Fitur ini juga masuk dalam jajaran atas, mempertegas bahwa perbedaan antara tipe Standard dan Full adalah informasi kunci bagi model untuk memprediksi harga secara akurat.
#
# Lalu untuk fitur dengan awalan 'highcard' merepresentasikan variabel kategori dengan jumlah nilai unik yang banyak seperti Make atau Type mobil yang telah diproses encoding. Kehadiran fitur-fitur ini dalam 10 besar Feature Importance menunjukkan bahwa identitas merk dan model spesifik tetap menjadi faktor pertimbangan model dalam menentukan estimasi harga, setelah fitur utama seperti tipe opsi dan usia kendaraan.

# %% [markdown]
# ## **Conclusion**
# Model yang digunakan untuk menerapkan machine learning dalam memprediksi harga mobil bekas adalah Extreme Gradient Boost (XGB). Cara XGB bekerja adalah model XGB membuat tree layaknya seperti model Random Forest, akan tetapi forest yang dibuat oleh XBG ini dibuat secara sequential dimana tree baru akan dibuat untuk memperbaiki error pada tree sebelumnya. Dalam dataset used cars ini direpresentasikan dengan cara berikut.
# - Tree pertama akan membuat prediksi harga secara kasar untuk setiap mobil di dataset.
# - Tree berikutnya akan membuat prediksi berdasarkan hasil error dari Tree pertama dan seterusnya sebanyak n_estimator pada hyperparameter tuning space.
#
#
# Berdasarkan analisis dataset 5.235 mobil bekas Arab Saudi, Option full terbukti menjadi faktor paling dominan dalam menentukan harga. Car_Age menunjukkan hubungan negatif terhadap harga, sementara Engine_Size memiliki korelasi positif lemah (r = 0.32). Hasil feature importance XGBoost mengkonfirmasi dominasi variabel Options_Full diikuti oleh Car_Age dan Engine_Size sebagai fitur berpengaruh.

# %% [markdown]
# ## **Recommendations**
#
# 1. Implementasi Model
# Model XGBoost setelah tuning menghasilkan R² = 0.611907 dan RMSE = 53,279 SAR, artinya rata-rata kesalahan prediksi sekitar 53,279 SAR. Model ini berpotensi diintegrasikan ke platform syarah.com sebagai fitur "Suggested Market Price" untuk membantu penjual menentukan harga yang kompetitif dan menghindari underpricing maupun overpricing.
#
# 2. Trade-off
# Meskipun performa model mengalami penurunan setelah dilakukan hyperparameter tuning, namun berdasarkan validasi menggunakan train dan test data ditemukan bahwa perbandingan nilai metric sebelum dan sesudah training untuk model setelah tuning memiliki persentase yang rendah (RMSE - 31.33%) dibandingkan model sebelum tuning (RMSE - 278.88%). Hal ini menunjukan bahwa model sebelum tuning memiliki score yang lebih rendah setelah tuning karena model mengalami overfitting dimana model sangat baik dalam melakukan prediksi pada training data tetapi underperform saat melakukan prediksi pada testing data.
#
# 3. Batasan Project
# Terdapat beberapa keterbatasan dalam project ini:
# Dataset hanya berasal dari syarah.com sehingga belum merepresentasikan seluruh pasar mobil bekas Arab Saudi dan
# fitur penting seperti kondisi fisik kendaraan, jumlah pemilik sebelumnya, dan riwayat servis tidak tersedia di dataset
# Model belum mempertimbangkan faktor eksternal seperti kondisi ekonomi dan fluktuasi harga pasar
#
# 4. Future Work
# Beberapa hal yang dapat dilakukan untuk mengembangkan model lebih lanjut:
#
# - Pertama, mengecek prediksi mana yang memiliki error tinggi dengan mengelompokkan ke dalam grup overestimation dan underestimation, lalu memilih 5% error paling ekstrim tiap grup. Dengan cara ini kita dapat mengetahui variabel mana yang menyebabkan error tinggi, sehingga dapat dilakukan feature engineering yang lebih tepat.
# - Kedua, jika memungkinkan, menambahkan fitur yang lebih korelatif dengan harga seperti kondisi fisik kendaraan (excellent/good/fair), riwayat servis, dan jumlah pemilik sebelumnya. Penambahan fitur ini berpotensi meningkatkan akurasi model di atas 88.7%.
# - Ketiga, membangun model terpisah untuk segmen budget car (< 50K SAR) dan premium car (> 150K SAR) untuk mengatasi kelemahan model pada kendaraan berharga rendah yang tercermin dari nilai MAPE yang tinggi.
# - Keempat, melakukan retraining model secara berkala seiring bertambahnya data listing baru di platform syarah.com agar model tetap relevan dengan kondisi pasar terkini.

# %% [markdown]
# ****

# %% [markdown]
# #### **Save Model**

# %%
# # Save model
import pickle

# pickle.dump(xgb_tuning, open('Used_cars_XGB.sav', 'wb'))

with open("Used_Cars_Regression_App/model/Used_cars_XGB.pkl", "wb") as f:

    pickle.dump(model, f)

# %%
# # Load model
# filename = 'Used_cars_XGB.sav'
# loaded_model = pickle.load(open(filename, 'rb'))

# y_pred_loaded = loaded_model.predict(X_test)

# rmse = np.sqrt(mean_squared_error(y_test, y_pred_loaded))
# mae  = mean_absolute_error(y_test, y_pred_loaded)
# mape = mean_absolute_percentage_error(y_test, y_pred_loaded)
# r2   = r2_score(y_test, y_pred_loaded)

# print("── Loaded Model Verification ──")
# print(f"  RMSE : {rmse:,.2f}")
# print(f"  MAE  : {mae:,.2f}")
# print(f"  MAPE : {mape:.4f} ({mape*100:.2f}%)")
# print(f"  R²   : {r2:.4f}")
